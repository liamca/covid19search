# %%
import globals

import re
from rank_bm25 import BM25Okapi
import math

import sqlite3
from sqlite3 import Error

import spacy
from spacy.tokens import DocBin
# Initialize spacy 'en' model, keeping only tagger component needed for lemmatization
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

from pathlib import Path
from shutil import rmtree
import os
from os import listdir
from os.path import isfile, join

import nltk
from nltk import sent_tokenize, tokenize, word_tokenize
nltk.download("punkt")

import sys
import tqdm
import json
from wasabi import msg
# Out:
# [nltk_data] Downloading package punkt to /home/liamca/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Reset bm25 dirs
globals.resetDir(globals.bm25_dir)
globals.resetDir(globals.bm25_tmp_dir)

# %%
# Merge all files into a single file
merged_text_path = Path(globals.merged_text_dir)
if merged_text_path.exists():
    rmtree(merged_text_path)
merged_text_path.mkdir(parents=True)

inFiles = globals.getFilesInDir(os.path.join(globals.processed_text_dir, globals.blob_container_path))

counter = 0
with open(os.path.join(globals.merged_text_dir, globals.merged_text_file_name), "wb") as mergedFile:
    for fileToProcess in inFiles:
        counter += 1
        if counter % 1000 == 0:
            print ("Merged file count:", counter)
        with open(os.path.join(globals.processed_text_dir, globals.blob_container_path, fileToProcess), "rb") as infile:
            mergedFile.write(infile.read())
print ("Merged file count:", counter)
# Out:
# Merged file count: 1000
# Merged file count: 2000
# Merged file count: 3000
# Merged file count: 4000
# Merged file count: 5000
# Merged file count: 6000
# Merged file count: 7000
# Merged file count: 8000
# Merged file count: 9000
# Merged file count: 10000
# Merged file count: 11000
# Merged file count: 12000
# Merged file count: 13000
# Merged file count: 14000
# Merged file count: 15000
# Merged file count: 16000
# Merged file count: 17000
# Merged file count: 18000
# Merged file count: 19000
# Merged file count: 20000
# Merged file count: 21000
# Merged file count: 22000
# Merged file count: 23000
# Merged file count: 24000
# Merged file count: 25000
# Merged file count: 26000
# Merged file count: 27000
# Merged file count: 28000
# Merged file count: 29000
# Merged file count: 29315

# %%
# Get the word counts over the merged file
# Get the avg word count 

print ("Get word counts over merged files...")

in_doc_counts = dict() 

total_word_count = 0.0
avg_word_count = 0.0
# Open the file in read mode 
text = open(os.path.join(globals.merged_text_dir, globals.merged_text_file_name), "r", encoding='utf-8') 
  
# This is the total bag of words counts across all docs
word_counts = dict() 

# This is the total word counts / doc
in_doc_total_word_counts = dict() 
  
# Loop through each line of the file 
doc_counter = 0
for line in text: 
    doc_counter += 1
    
    # Remove the leading spaces and newline character 
    line = line.strip() 
  
    # Split the line into words 
    words = line.split(" ") 
    total_word_count += len(words)
  
    in_doc_total_word_counts[doc_counter] = len(words)

    # Iterate over each word in line 
    sc = {}
    for word in words: 
        if word in word_counts: 
            word_counts[word] = word_counts[word] + 1
        else: 
            word_counts[word] = 1
            
        if word in sc:
            sc[word] = sc[word] + 1
        else:
            sc[word] = 1
        
    in_doc_counts[doc_counter] = sc

print ("Get avg word counts...")

avg_word_count = total_word_count / doc_counter

totalDocCount = doc_counter
# Out:
# Get word counts over merged files...
# Get avg word counts...

# %%
bm25Values = dict() 

count1 = 0
count2 = 0
print ("Calculating avg BM25 values...")

word_count_keys_as_list = list(word_counts.keys())
word_count_keys_len = len(word_count_keys_as_list)
word_count_key_counter = 0
print ('Total terms to process:', word_count_keys_len)

in_doc_counts_keys_as_list = list(in_doc_counts.keys())
# Get the number of sentences 
in_doc_counts_len = len(in_doc_counts_keys_as_list)
in_doc_counts_counter = 0
# Out:
# Calculating avg BM25 values...
# Total terms to process: 1357726

# %%
# convert the in_doc_counts to a dataframe so it can be processed faster
print ("Writing doc term counts to text...")

counter = 0
with open(os.path.join(globals.bm25_tmp_dir, "doc_terms.txt"), "w", encoding="utf-8") as outfile: 
    for doc_key in list(in_doc_counts.keys()):
        counter += 1
        if counter % 100000 == 0:
            print ("Completed", counter, "of", in_doc_counts_len, "...")
        for doc_term in in_doc_counts[doc_key]:
            outfile.write(str(doc_key) + '\t' + str(doc_term) + '\t' + str(in_doc_counts[doc_key][doc_term]) + '\r\n') 
print ("Completed", counter, "of", in_doc_counts_len, "...")
# Out:
# Writing doc term counts to text...
# Completed 100000 of 1110994 ...
# Completed 200000 of 1110994 ...
# Completed 300000 of 1110994 ...
# Completed 400000 of 1110994 ...
# Completed 500000 of 1110994 ...
# Completed 600000 of 1110994 ...
# Completed 700000 of 1110994 ...
# Completed 800000 of 1110994 ...
# Completed 900000 of 1110994 ...
# Completed 1000000 of 1110994 ...
# Completed 1100000 of 1110994 ...
# Completed 1110994 of 1110994 ...

# %%
# load the doc terms into a indexed sqlite db
print ("Loading doc term counts into indexed db...")

conn = sqlite3.connect(os.path.join(globals.bm25_tmp_dir,"bm25.sqlite"))
try:
    sql = "drop table if exists doc_terms"
    conn.execute(sql)
    sql = "create table doc_terms (doc_key int, term text, count int)"
    conn.execute(sql)
except Error as e:
    print(e)
# Out:
# Loading doc term counts into indexed db...

# %%
# load the doc terms
count = 0
rows = []
c = conn.cursor()
with open(os.path.join(globals.bm25_tmp_dir, "doc_terms.txt"), encoding='utf-8') as fp: 
    while True: 
        line = fp.readline() 
        if not line: 
            break

        fields = line.split('\t')
        rows.append((fields[0], fields[1], fields[2]))
        count += 1
        if count % 100000 == 0: 
            sql = 'insert into doc_terms (doc_key, term, count) values (?,?,?)'
            c.executemany(sql, rows)
            conn.commit()
            print ("Inserted:", str(count))
            rows = []
if len(rows) > 0:
    sql = 'insert into doc_terms (doc_key, term, count) values (?,?,?)'
    c.executemany(sql, rows)
    conn.commit()
    print ("Inserted:", str(count))
    
print ("Creating indexes...")
sql = "create index idx_doc_terms_doc_key on doc_terms (doc_key)"
conn.execute(sql)
sql = "create index idx_doc_terms_terms on doc_terms (term)"
conn.execute(sql)
# Out:
# Inserted: 100000
# Inserted: 200000
# Inserted: 300000
# Inserted: 400000
# Inserted: 500000
# Inserted: 600000
# Inserted: 700000
# Inserted: 800000
# Inserted: 900000
# Inserted: 1000000
# Inserted: 1100000
# Inserted: 1200000
# Inserted: 1300000
# Inserted: 1400000
# Inserted: 1500000
# Inserted: 1600000
# Inserted: 1700000
# Inserted: 1800000
# Inserted: 1900000
# Inserted: 2000000
# Inserted: 2100000
# Inserted: 2200000
# Inserted: 2300000
# Inserted: 2400000
# Inserted: 2500000
# Inserted: 2600000
# Inserted: 2700000
# Inserted: 2800000
# Inserted: 2900000
# Inserted: 3000000
# Inserted: 3100000
# Inserted: 3200000
# Inserted: 3300000
# Inserted: 3400000
# Inserted: 3500000
# Inserted: 3600000
# Inserted: 3700000
# Inserted: 3800000
# Inserted: 3900000
# Inserted: 4000000
# Inserted: 4100000
# Inserted: 4200000
# Inserted: 4300000
# Inserted: 4400000
# Inserted: 4500000
# Inserted: 4600000
# Inserted: 4700000
# Inserted: 4800000
# Inserted: 4900000
# Inserted: 5000000
# Inserted: 5100000
# Inserted: 5200000
# Inserted: 5300000
# Inserted: 5400000
# Inserted: 5500000
# Inserted: 5600000
# Inserted: 5700000
# Inserted: 5800000
# Inserted: 5900000
# Inserted: 6000000
# Inserted: 6100000
# Inserted: 6200000
# Inserted: 6300000
# Inserted: 6400000
# Inserted: 6500000
# Inserted: 6600000
# Inserted: 6700000
# Inserted: 6800000
# Inserted: 6900000
# Inserted: 7000000
# Inserted: 7100000
# Inserted: 7200000
# Inserted: 7300000
# Inserted: 7400000
# Inserted: 7500000
# Inserted: 7600000
# Inserted: 7700000
# Inserted: 7800000
# Inserted: 7900000
# Inserted: 8000000
# Inserted: 8100000
# Inserted: 8200000
# Inserted: 8300000
# Inserted: 8400000
# Inserted: 8500000
# Inserted: 8600000
# Inserted: 8700000
# Inserted: 8800000
# Inserted: 8900000
# Inserted: 9000000
# Inserted: 9100000
# Inserted: 9200000
# Inserted: 9300000
# Inserted: 9400000
# Inserted: 9500000
# Inserted: 9600000
# Inserted: 9700000
# Inserted: 9800000
# Inserted: 9900000
# Inserted: 10000000
# Inserted: 10100000
# Inserted: 10200000
# Inserted: 10300000
# Inserted: 10400000
# Inserted: 10500000
# Inserted: 10600000
# Inserted: 10700000
# Inserted: 10800000
# Inserted: 10900000
# Inserted: 11000000
# Inserted: 11100000
# Inserted: 11200000
# Inserted: 11300000
# Inserted: 11400000
# Inserted: 11500000
# Inserted: 11600000
# Inserted: 11700000
# Inserted: 11800000
# Inserted: 11900000
# Inserted: 12000000
# Inserted: 12100000
# Inserted: 12200000
# Inserted: 12300000
# Inserted: 12400000
# Inserted: 12500000
# Inserted: 12600000
# Inserted: 12700000
# Inserted: 12800000
# Inserted: 12900000
# Inserted: 13000000
# Inserted: 13100000
# Inserted: 13200000
# Inserted: 13300000
# Inserted: 13400000
# Inserted: 13500000
# Inserted: 13600000
# Inserted: 13700000
# Inserted: 13800000
# Inserted: 13900000
# Inserted: 14000000
# Inserted: 14100000
# Inserted: 14200000
# Inserted: 14300000
# Inserted: 14400000
# Inserted: 14500000
# Inserted: 14600000
# Inserted: 14700000
# Inserted: 14800000
# Inserted: 14900000
# Inserted: 15000000
# Inserted: 15100000
# Inserted: 15200000
# Inserted: 15300000
# Inserted: 15400000
# Inserted: 15500000
# Inserted: 15600000
# Inserted: 15700000
# Inserted: 15800000
# Inserted: 15900000
# Inserted: 16000000
# Inserted: 16100000
# Inserted: 16200000
# Inserted: 16300000
# Inserted: 16400000
# Inserted: 16500000
# Inserted: 16600000
# Inserted: 16700000
# Inserted: 16800000
# Inserted: 16900000
# Inserted: 17000000
# Inserted: 17100000
# Inserted: 17200000
# Inserted: 17300000
# Inserted: 17400000
# Inserted: 17500000
# Inserted: 17600000
# Inserted: 17700000
# Inserted: 17800000
# Inserted: 17900000
# Inserted: 18000000
# Inserted: 18100000
# Inserted: 18200000
# Inserted: 18300000
# Inserted: 18400000
# Inserted: 18500000
# Inserted: 18600000
# Inserted: 18700000
# Inserted: 18800000
# Inserted: 18900000
# Inserted: 19000000
# Inserted: 19100000
# Inserted: 19200000
# Inserted: 19300000
# Inserted: 19400000
# Inserted: 19500000
# Inserted: 19600000
# Inserted: 19700000
# Inserted: 19800000
# Inserted: 19900000
# Inserted: 20000000
# Inserted: 20100000
# Inserted: 20200000
# Inserted: 20300000
# Inserted: 20400000
# Inserted: 20500000
# Inserted: 20600000
# Inserted: 20700000
# Inserted: 20800000
# Inserted: 20900000
# Inserted: 21000000
# Inserted: 21100000
# Inserted: 21200000
# Inserted: 21300000
# Inserted: 21400000
# Inserted: 21500000
# Inserted: 21600000
# Inserted: 21700000
# Inserted: 21800000
# Inserted: 21900000
# Inserted: 22000000
# Inserted: 22100000
# Inserted: 22200000
# Inserted: 22300000
# Inserted: 22400000
# Inserted: 22500000
# Inserted: 22600000
# Inserted: 22700000
# Inserted: 22800000
# Inserted: 22900000
# Inserted: 23000000
# Inserted: 23100000
# Inserted: 23200000
# Inserted: 23300000
# Inserted: 23400000
# Inserted: 23500000
# Inserted: 23600000
# Inserted: 23700000
# Inserted: 23800000
# Inserted: 23900000
# Inserted: 24000000
# Inserted: 24100000
# Inserted: 24200000
# Inserted: 24300000
# Inserted: 24400000
# Inserted: 24500000
# Inserted: 24600000
# Inserted: 24700000
# Inserted: 24800000
# Inserted: 24900000
# Inserted: 25000000
# Inserted: 25100000
# Inserted: 25200000
# Inserted: 25300000
# Inserted: 25400000
# Inserted: 25500000
# Inserted: 25600000
# Inserted: 25700000
# Inserted: 25800000
# Inserted: 25900000
# Inserted: 26000000
# Inserted: 26100000
# Inserted: 26200000
# Inserted: 26300000
# Inserted: 26400000
# Inserted: 26500000
# Inserted: 26600000
# Inserted: 26700000
# Inserted: 26800000
# Inserted: 26900000
# Inserted: 27000000
# Inserted: 27100000
# Inserted: 27200000
# Inserted: 27300000
# Inserted: 27400000
# Inserted: 27500000
# Inserted: 27600000
# Inserted: 27700000
# Inserted: 27800000
# Inserted: 27900000
# Inserted: 28000000
# Inserted: 28100000
# Inserted: 28200000
# Inserted: 28300000
# Inserted: 28400000
# Inserted: 28500000
# Inserted: 28600000
# Inserted: 28700000
# Inserted: 28800000
# Inserted: 28900000
# Inserted: 29000000
# Inserted: 29100000
# Inserted: 29200000
# Inserted: 29300000
# Inserted: 29400000
# Inserted: 29500000
# Inserted: 29600000
# Inserted: 29700000
# Inserted: 29800000
# Inserted: 29900000
# Inserted: 30000000
# Inserted: 30100000
# Inserted: 30200000
# Inserted: 30300000
# Inserted: 30400000
# Inserted: 30500000
# Inserted: 30600000
# Inserted: 30700000
# Inserted: 30800000
# Inserted: 30900000
# Inserted: 31000000
# Inserted: 31100000
# Inserted: 31200000
# Inserted: 31300000
# Inserted: 31400000
# Inserted: 31500000
# Inserted: 31600000
# Inserted: 31700000
# Inserted: 31800000
# Inserted: 31900000
# Inserted: 32000000
# Inserted: 32100000
# Inserted: 32200000
# Inserted: 32300000
# Inserted: 32400000
# Inserted: 32500000
# Inserted: 32600000
# Inserted: 32700000
# Inserted: 32800000
# Inserted: 32900000
# Inserted: 33000000
# Inserted: 33100000
# Inserted: 33200000
# Inserted: 33300000
# Inserted: 33400000
# Inserted: 33500000
# Inserted: 33600000
# Inserted: 33700000
# Inserted: 33800000
# Inserted: 33900000
# Inserted: 34000000
# Inserted: 34100000
# Inserted: 34200000
# Inserted: 34300000
# Inserted: 34400000
# Inserted: 34500000
# Inserted: 34600000
# Inserted: 34700000
# Inserted: 34800000
# Inserted: 34900000
# Inserted: 35000000
# Inserted: 35100000
# Inserted: 35200000
# Inserted: 35300000
# Inserted: 35400000
# Inserted: 35500000
# Inserted: 35600000
# Inserted: 35700000
# Inserted: 35800000
# Inserted: 35900000
# Inserted: 36000000
# Inserted: 36100000
# Inserted: 36200000
# Inserted: 36300000
# Inserted: 36400000
# Inserted: 36500000
# Inserted: 36600000
# Inserted: 36700000
# Inserted: 36800000
# Inserted: 36900000
# Inserted: 37000000
# Inserted: 37100000
# Inserted: 37200000
# Inserted: 37300000
# Inserted: 37400000
# Inserted: 37500000
# Inserted: 37600000
# Inserted: 37700000
# Inserted: 37800000
# Inserted: 37900000
# Inserted: 38000000
# Inserted: 38100000
# Inserted: 38200000
# Inserted: 38300000
# Inserted: 38400000
# Inserted: 38500000
# Inserted: 38600000
# Inserted: 38700000
# Inserted: 38800000
# Inserted: 38900000
# Inserted: 39000000
# Inserted: 39100000
# Inserted: 39200000
# Inserted: 39300000
# Inserted: 39400000
# Inserted: 39500000
# Inserted: 39600000
# Inserted: 39700000
# Inserted: 39800000
# Inserted: 39900000
# Inserted: 40000000
# Inserted: 40100000
# Inserted: 40200000
# Inserted: 40300000
# Inserted: 40400000
# Inserted: 40500000
# Inserted: 40600000
# Inserted: 40700000
# Inserted: 40800000
# Inserted: 40900000
# Inserted: 41000000
# Inserted: 41100000
# Inserted: 41200000
# Inserted: 41300000
# Inserted: 41400000
# Inserted: 41500000
# Inserted: 41600000
# Inserted: 41700000
# Inserted: 41800000
# Inserted: 41900000
# Inserted: 42000000
# Inserted: 42100000
# Inserted: 42200000
# Inserted: 42300000
# Inserted: 42400000
# Inserted: 42500000
# Inserted: 42600000
# Inserted: 42700000
# Inserted: 42800000
# Inserted: 42900000
# Inserted: 43000000
# Inserted: 43100000
# Inserted: 43200000
# Inserted: 43300000
# Inserted: 43400000
# Inserted: 43500000
# Inserted: 43600000
# Inserted: 43700000
# Inserted: 43800000
# Inserted: 43900000
# Inserted: 44000000
# Inserted: 44100000
# Inserted: 44200000
# Inserted: 44300000
# Inserted: 44400000
# Inserted: 44500000
# Inserted: 44600000
# Inserted: 44700000
# Inserted: 44800000
# Inserted: 44900000
# Inserted: 45000000
# Inserted: 45100000
# Inserted: 45200000
# Inserted: 45300000
# Inserted: 45400000
# Inserted: 45500000
# Inserted: 45600000
# Inserted: 45700000
# Inserted: 45800000
# Inserted: 45900000
# Inserted: 46000000
# Inserted: 46100000
# Inserted: 46200000
# Inserted: 46300000
# Inserted: 46400000
# Inserted: 46500000
# Inserted: 46600000
# Inserted: 46700000
# Inserted: 46800000
# Inserted: 46900000
# Inserted: 47000000
# Inserted: 47100000
# Inserted: 47200000
# Inserted: 47300000
# Inserted: 47400000
# Inserted: 47500000
# Inserted: 47600000
# Inserted: 47700000
# Inserted: 47800000
# Inserted: 47900000
# Inserted: 48000000
# Inserted: 48100000
# Inserted: 48200000
# Inserted: 48300000
# Inserted: 48400000
# Inserted: 48500000
# Inserted: 48600000
# Inserted: 48700000
# Inserted: 48800000
# Inserted: 48900000
# Inserted: 49000000
# Inserted: 49100000
# Inserted: 49200000
# Inserted: 49300000
# Inserted: 49400000
# Inserted: 49500000
# Inserted: 49600000
# Inserted: 49700000
# Inserted: 49800000
# Inserted: 49900000
# Inserted: 50000000
# Inserted: 50100000
# Inserted: 50200000
# Inserted: 50300000
# Inserted: 50400000
# Inserted: 50500000
# Inserted: 50600000
# Inserted: 50700000
# Inserted: 50800000
# Inserted: 50900000
# Inserted: 51000000
# Inserted: 51100000
# Inserted: 51200000
# Inserted: 51300000
# Inserted: 51400000
# Inserted: 51500000
# Inserted: 51600000
# Inserted: 51700000
# Inserted: 51800000
# Inserted: 51900000
# Inserted: 52000000
# Inserted: 52100000
# Inserted: 52200000
# Inserted: 52300000
# Inserted: 52400000
# Inserted: 52500000
# Inserted: 52600000
# Inserted: 52700000
# Inserted: 52800000
# Inserted: 52900000
# Inserted: 53000000
# Inserted: 53100000
# Inserted: 53200000
# Inserted: 53300000
# Inserted: 53400000
# Inserted: 53500000
# Inserted: 53600000
# Inserted: 53700000
# Inserted: 53800000
# Inserted: 53900000
# Inserted: 54000000
# Inserted: 54100000
# Inserted: 54200000
# Inserted: 54300000
# Inserted: 54400000
# Inserted: 54500000
# Inserted: 54600000
# Inserted: 54700000
# Inserted: 54800000
# Inserted: 54900000
# Inserted: 55000000
# Inserted: 55100000
# Inserted: 55200000
# Inserted: 55300000
# Inserted: 55400000
# Inserted: 55500000
# Inserted: 55600000
# Inserted: 55700000
# Inserted: 55800000
# Inserted: 55900000
# Inserted: 56000000
# Inserted: 56100000
# Inserted: 56200000
# Inserted: 56300000
# Inserted: 56400000
# Inserted: 56500000
# Inserted: 56600000
# Inserted: 56700000
# Inserted: 56800000
# Inserted: 56900000
# Inserted: 57000000
# Inserted: 57100000
# Inserted: 57200000
# Inserted: 57300000
# Inserted: 57400000
# Inserted: 57500000
# Inserted: 57600000
# Inserted: 57700000
# Inserted: 57800000
# Inserted: 57900000
# Inserted: 58000000
# Inserted: 58100000
# Inserted: 58200000
# Inserted: 58300000
# Inserted: 58400000
# Inserted: 58500000
# Inserted: 58600000
# Inserted: 58700000
# Inserted: 58800000
# Inserted: 58900000
# Inserted: 59000000
# Inserted: 59100000
# Inserted: 59200000
# Inserted: 59300000
# Inserted: 59400000
# Inserted: 59500000
# Inserted: 59600000
# Inserted: 59700000
# Inserted: 59800000
# Inserted: 59900000
# Inserted: 60000000
# Inserted: 60100000
# Inserted: 60200000
# Inserted: 60300000
# Inserted: 60400000
# Inserted: 60500000
# Inserted: 60600000
# Inserted: 60700000
# Inserted: 60800000
# Inserted: 60900000
# Inserted: 61000000
# Inserted: 61100000
# Inserted: 61200000
# Inserted: 61300000
# Inserted: 61400000
# Inserted: 61500000
# Inserted: 61600000
# Inserted: 61700000
# Inserted: 61800000
# Inserted: 61900000
# Inserted: 62000000
# Inserted: 62100000
# Inserted: 62200000
# Inserted: 62300000
# Inserted: 62400000
# Inserted: 62500000
# Inserted: 62600000
# Inserted: 62700000
# Inserted: 62800000
# Inserted: 62900000
# Inserted: 63000000
# Inserted: 63100000
# Inserted: 63200000
# Inserted: 63300000
# Inserted: 63326120
# Creating indexes...

# %%
counter = 0
for key in word_count_keys_as_list: 
    counter += 1
    if counter % 100 == 0:
        print ("Completed", counter, "of", word_count_keys_len, "...")
    uniqueWord = key
#     print ('uniqueWord: ', uniqueWord)
    
    bm25Total = 0.0
    wordCounter = 0.0
    avgBM25 = 0.0

    try:
        # get all the docs that contain this uniqueword
        cur = conn.cursor()
        cur.execute("SELECT doc_key, count FROM doc_terms WHERE term=?", (uniqueWord,))
        rows = cur.fetchall()

        for row in rows:
            wordCountOfThisDoc = row[0]
            termFreqInDocument = row[1]
            termFreqInIndex = word_counts[key]
            this_bm25 = math.log((totalDocCount - termFreqInIndex + 0.5) / (termFreqInIndex + 0.5)) * (termFreqInDocument * (globals.k1 + 1)) / (termFreqInDocument + globals.k1 * (1 - globals.b + (globals.b * wordCountOfThisDoc / avg_word_count)))
            bm25Total += this_bm25
            wordCounter += 1
        avgBM25 = bm25Total / wordCounter
        if avgBM25 < 0:
            avgBM25 = 0
         
    except Exception as e:
        ## as long as it is not a divid b 0, print error
        if str(e) != 'math domain error':
            print("error:", e)
        bm25Values[uniqueWord] = 0
    bm25Values[uniqueWord] = avgBM25
# Out:
# Completed 100 of 1357726 ...
# Completed 200 of 1357726 ...
# Completed 300 of 1357726 ...
# Completed 400 of 1357726 ...
# Completed 500 of 1357726 ...
# Completed 600 of 1357726 ...
# Completed 700 of 1357726 ...
# Completed 800 of 1357726 ...
# Completed 900 of 1357726 ...
# Completed 1000 of 1357726 ...
# Completed 1100 of 1357726 ...
# Completed 1200 of 1357726 ...
# Completed 1300 of 1357726 ...
# Completed 1400 of 1357726 ...
# Completed 1500 of 1357726 ...
# Completed 1600 of 1357726 ...
# Completed 1700 of 1357726 ...
# Completed 1800 of 1357726 ...
# Completed 1900 of 1357726 ...
# Completed 2000 of 1357726 ...
# Completed 2100 of 1357726 ...
# Completed 2200 of 1357726 ...
# Completed 2300 of 1357726 ...
# Completed 2400 of 1357726 ...
# Completed 2500 of 1357726 ...
# Completed 2600 of 1357726 ...
# Completed 2700 of 1357726 ...
# Completed 2800 of 1357726 ...
# Completed 2900 of 1357726 ...
# Completed 3000 of 1357726 ...
# Completed 3100 of 1357726 ...
# Completed 3200 of 1357726 ...
# Completed 3300 of 1357726 ...
# Completed 3400 of 1357726 ...
# Completed 3500 of 1357726 ...
# Completed 3600 of 1357726 ...
# Completed 3700 of 1357726 ...
# Completed 3800 of 1357726 ...
# Completed 3900 of 1357726 ...
# Completed 4000 of 1357726 ...
# Completed 4100 of 1357726 ...
# Completed 4200 of 1357726 ...
# Completed 4300 of 1357726 ...
# Completed 4400 of 1357726 ...
# Completed 4500 of 1357726 ...
# Completed 4600 of 1357726 ...
# Completed 4700 of 1357726 ...
# Completed 4800 of 1357726 ...
# Completed 4900 of 1357726 ...
# Completed 5000 of 1357726 ...
# Completed 5100 of 1357726 ...
# Completed 5200 of 1357726 ...
# Completed 5300 of 1357726 ...
# Completed 5400 of 1357726 ...
# Completed 5500 of 1357726 ...
# Completed 5600 of 1357726 ...
# Completed 5700 of 1357726 ...
# Completed 5800 of 1357726 ...
# Completed 5900 of 1357726 ...
# Completed 6000 of 1357726 ...
# Completed 6100 of 1357726 ...
# Completed 6200 of 1357726 ...
# Completed 6300 of 1357726 ...
# Completed 6400 of 1357726 ...
# Completed 6500 of 1357726 ...
# Completed 6600 of 1357726 ...
# Completed 6700 of 1357726 ...
# Completed 6800 of 1357726 ...
# Completed 6900 of 1357726 ...
# Completed 7000 of 1357726 ...
# Completed 7100 of 1357726 ...
# Completed 7200 of 1357726 ...
# Completed 7300 of 1357726 ...
# Completed 7400 of 1357726 ...
# Completed 7500 of 1357726 ...
# Completed 7600 of 1357726 ...
# Completed 7700 of 1357726 ...
# Completed 7800 of 1357726 ...
# Completed 7900 of 1357726 ...
# Completed 8000 of 1357726 ...
# Completed 8100 of 1357726 ...
# Completed 8200 of 1357726 ...
# Completed 8300 of 1357726 ...
# Completed 8400 of 1357726 ...
# Completed 8500 of 1357726 ...
# Completed 8600 of 1357726 ...
# Completed 8700 of 1357726 ...
# Completed 8800 of 1357726 ...
# Completed 8900 of 1357726 ...
# Completed 9000 of 1357726 ...
# Completed 9100 of 1357726 ...
# Completed 9200 of 1357726 ...
# Completed 9300 of 1357726 ...
# Completed 9400 of 1357726 ...
# Completed 9500 of 1357726 ...
# Completed 9600 of 1357726 ...
# Completed 9700 of 1357726 ...
# Completed 9800 of 1357726 ...
# Completed 9900 of 1357726 ...
# Completed 10000 of 1357726 ...
# Completed 10100 of 1357726 ...
# Completed 10200 of 1357726 ...
# Completed 10300 of 1357726 ...
# Completed 10400 of 1357726 ...
# Completed 10500 of 1357726 ...
# Completed 10600 of 1357726 ...
# Completed 10700 of 1357726 ...
# Completed 10800 of 1357726 ...
# Completed 10900 of 1357726 ...
# Completed 11000 of 1357726 ...
# Completed 11100 of 1357726 ...
# Completed 11200 of 1357726 ...
# Completed 11300 of 1357726 ...
# Completed 11400 of 1357726 ...
# Completed 11500 of 1357726 ...
# Completed 11600 of 1357726 ...
# Completed 11700 of 1357726 ...
# Completed 11800 of 1357726 ...
# Completed 11900 of 1357726 ...
# Completed 12000 of 1357726 ...
# Completed 12100 of 1357726 ...
# Completed 12200 of 1357726 ...
# Completed 12300 of 1357726 ...
# Completed 12400 of 1357726 ...
# Completed 12500 of 1357726 ...
# Completed 12600 of 1357726 ...
# Completed 12700 of 1357726 ...
# Completed 12800 of 1357726 ...
# Completed 12900 of 1357726 ...
# Completed 13000 of 1357726 ...
# Completed 13100 of 1357726 ...
# Completed 13200 of 1357726 ...
# Completed 13300 of 1357726 ...
# Completed 13400 of 1357726 ...
# Completed 13500 of 1357726 ...
# Completed 13600 of 1357726 ...
# Completed 13700 of 1357726 ...
# Completed 13800 of 1357726 ...
# Completed 13900 of 1357726 ...
# Completed 14000 of 1357726 ...
# Completed 14100 of 1357726 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-08e3cbc09303> in <module>
#      15         cur = conn.cursor()
#      16         cur.execute("SELECT doc_key, count FROM doc_terms WHERE term=?", (uniqueWord,))
# ---> 17         rows = cur.fetchall()
#      18
#      19         for row in rows:
#
# KeyboardInterrupt:

# %%
# write avg bm25 values to file
print ("Writing avg BM25 values...")

with open(os.path.join(globals.bm25_dir, globals.bm25_file), 'w', encoding='utf-8') as f:
    for bm25_key in list(bm25Values.keys()):
        f.write(bm25_key + '\t' + str(bm25Values[bm25_key]) + '\r\n')
