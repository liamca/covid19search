# %%
# Take all JSON from Blob Container and upload to Azure Search

# %%
import globals

import os
import pickle

import json
import requests
from pprint import pprint

from nltk.tokenize import sent_tokenize, word_tokenize

import time

from joblib import Parallel, delayed

# %%
max_sentences = 25

# %%
def processFile(data):
    try:
        json_response = requests.post(url = globals.ta_base_url, json= data).json()
        return json_response
    except Exception as ex:
        return {"error": [str(ex)]}


def createSearchUploadDoc(docID, json_content):
    try:
               
        CONDITION_QUALIFIER = []
        DIAGNOSIS = []
        DIRECTION = []
        EXAMINATION_NAME = []
        EXAMINATION_RELATION = []
        FAMILY_RELATION = []
        GENDER = []
        GENE = []
        MEDICATION_CLASS = []
        MEDICATION_NAME = []
        ROUTE_OR_MODE = []
        SYMPTOM_OR_SIGN = []
        TREATMENT_NAME = []
        BODY_STRUCTURE = []
        VARIANT = []

        
#         remove if negated....

        for doc in json_content['documents']:
            for ent in doc['entities']:
                if 'links' in ent:
                    if 'category' in ent:
                        for link in ent['links']:
                            if 'UMLS' in str(link):
                                if link['id'] in umls_concept_dict:
                                    if ent['category'] == 'TreatmentName':
                                        TREATMENT_NAME.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'BodyStructure':
                                        BODY_STRUCTURE.append(umls_concept_dict[link['id']])
                                    if ent['category'] == 'ConditionQualifier':
                                        CONDITION_QUALIFIER.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'Diagnosis':
                                        DIAGNOSIS.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'Direction':
                                        DIRECTION.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'ExaminationName':
                                        EXAMINATION_NAME.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'ExaminationRelation':
                                        EXAMINATION_RELATION.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'FamilyRelation':
                                        FAMILY_RELATION.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'Gender':
                                        GENDER.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'Gene':
                                        GENE.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'MedicationClass':
                                        MEDICATION_CLASS.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'MedicationName':
                                        MEDICATION_NAME.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'RouteOrMode':
                                        ROUTE_OR_MODE.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'SymptomOrSign':
                                        SYMPTOM_OR_SIGN.append(umls_concept_dict[link['id']])
                                    elif ent['category'] == 'Variant':
                                        VARIANT.append(umls_concept_dict[link['id']])

                                

        #unique terms and back to list
        BODY_STRUCTURE = list(set(BODY_STRUCTURE))
        CONDITION_QUALIFIER = list(set(CONDITION_QUALIFIER))
        DIAGNOSIS = list(set(DIAGNOSIS))
        DIRECTION = list(set(DIRECTION))
        EXAMINATION_NAME = list(set(EXAMINATION_NAME))
        EXAMINATION_RELATION = list(set(EXAMINATION_RELATION))
        FAMILY_RELATION = list(set(FAMILY_RELATION))
        GENDER = list(set(GENDER))
        GENE = list(set(GENE))
        MEDICATION_CLASS = list(set(MEDICATION_CLASS))
        MEDICATION_NAME = list(set(MEDICATION_NAME))
        ROUTE_OR_MODE = list(set(ROUTE_OR_MODE))
        SYMPTOM_OR_SIGN = list(set(SYMPTOM_OR_SIGN))
        TREATMENT_NAME = list(set(TREATMENT_NAME))
        VARIANT = list(set(VARIANT))

        return {"@search.action": "merge","docID": docID, "appliedMedicalEntities": True, "treatmentName":TREATMENT_NAME, "examinationName": EXAMINATION_NAME, 
                                   "bodyStructure": BODY_STRUCTURE, "diagnosis": DIAGNOSIS, "conditionQualifier": CONDITION_QUALIFIER, "direction": DIRECTION,
                                   "examinationRelation": EXAMINATION_RELATION, "familyRelation": FAMILY_RELATION, "gender": GENDER, "gene": GENE,
                                   "medicationClass": MEDICATION_CLASS, "medicationName": MEDICATION_NAME, "routeOrMode": ROUTE_OR_MODE, "symptomOrSign": SYMPTOM_OR_SIGN,
                                  "variant": VARIANT, "taHealthJSON": str(json_content)}
#         documents = {"value": []}
#         documents["value"].append({"@search.action": "merge","docID": docID, "treatmentName":TREATMENT_NAME, "examinationName": EXAMINATION_NAME, 
#                                    "bodyStructure": BODY_STRUCTURE, "diagnosis": DIAGNOSIS, "conditionQualifier": CONDITION_QUALIFIER, "direction": DIRECTION,
#                                    "examinationRelation": EXAMINATION_RELATION, "familyRelation": FAMILY_RELATION, "gender": GENDER, "gene": GENE,
#                                    "medicationClass": MEDICATION_CLASS, "medicationName": MEDICATION_NAME, "routeOrMode": ROUTE_OR_MODE, "symptomOrSign": SYMPTOM_OR_SIGN,
#                                   "variant": VARIANT})
#         url = globals.endpoint + "indexes/" + globals.indexName + "/docs/index" + globals.api_version
#         response  = requests.post(url, headers=globals.headers, json=documents)

    except Exception as ex:
        print ("Error:", ex)
        return {"@search.action": "merge","docID": docID}

# %%
# Load the UMLS dictionary of concept id's to names
with open(os.path.join(globals.umls_dir, 'umls_concept_dict.pickle'), 'rb') as handle:
    umls_concept_dict = pickle.load(handle)

# %%
def createTAHealthDoc(title, abstract, body):
    data = {"documents": []}

    try:
        id_counter = 0
        if len(title) > 1:
            id_counter += 1
            data["documents"].append({"language": "en","id": str(id_counter),"text": title})

        id_counter += 1
        if (len(abstract.strip())) > 1:
            data["documents"].append({"language": "en","id": str(id_counter),"text": abstract})
        else:
            data["documents"].append({"language": "en","id": str(id_counter),"text": body[0:5000]})

    except Exception as ex:
            print ("Error:", ex)

    return data

# %%
print ("Uploading concepts to Azure Cognitive Search...")

# Get a document that has not been completed
url = globals.endpoint + "indexes/" + globals.indexName + "/docs" + globals.api_version + "&$count=true&$top=20&search=*&$select=docID,title,abstractContent,body&$filter=appliedMedicalEntities eq null"
response  = requests.get(url, headers=globals.headers)
docs = response.json()

while len(docs["value"]) > 0:
    print ('[' +  str(docs['@odata.count']) + " left]...")
    for doc in docs["value"]:
        docID = doc['docID']

        ta_health_doc = createTAHealthDoc(doc["title"], doc["abstractContent"], doc["body"])
        print ("Processing docID:", docID, "[Len: " + str(len(str(ta_health_doc))) + "]")

        ta_health_resp = processFile(ta_health_doc)
        if 'error' not in ta_health_resp:
            search_upload = createSearchUploadDoc(docID, ta_health_resp)

            documents = {"value": []}
            documents["value"].append(search_upload)
            url = globals.endpoint + "indexes/" + globals.indexName + "/docs/index" + globals.api_version
        else:
            print ('Error - Will Apply Empty Concepts: ', ta_health_resp['error'])
            documents = {"value": []}
            search_upload = {"@search.action": "merge","docID": docID, "appliedMedicalEntities": True}
            documents["value"].append(search_upload)
            url = globals.endpoint + "indexes/" + globals.indexName + "/docs/index" + globals.api_version
            time.sleep(3)

        upload_response  = requests.post(url, headers=globals.headers, json=documents)

        if upload_response.json()['value'][0]['status'] != True:
            print ("Error:", upload_response.json()['value'][0]['errorMessage'])

            
    # Get another doc...
    url = globals.endpoint + "indexes/" + globals.indexName + "/docs" + globals.api_version + "&$count=true&$top=20&search=*&$select=docID,title,abstractContent,body&$filter=appliedMedicalEntities eq null"
    response  = requests.get(url, headers=globals.headers)
    docs = response.json()
# Out:
# Uploading concepts to Azure Cognitive Search...
# [24364 left]...
# Processing docID: 03069298205fe6b0be10fbd78556aa4b8c772ade [Len: 3184]
# Processing docID: 4ddf5d95158203e4053fba41b1d3fe3948a5d9a3 [Len: 5238]
# Processing docID: d682465041554fddc9e1dbc626bae7a0a512c631 [Len: 1152]
# Processing docID: a7e361f72a101cc83a7e59d48f3378c404953fb7 [Len: 5058]
# Processing docID: 96aa124328bbf7a4035a9bbeb0781fd88b1e0328 [Len: 5038]
# Processing docID: f63f9fc68b5246d913e6d243e06f229729c917a5 [Len: 6026]
# Processing docID: 063561d8ab083c6a70826e25d2ce7b72cb9ee5b4 [Len: 5058]
# Processing docID: 7a7aa345486356561071e652c8433da5fe613afe [Len: 543]
# Processing docID: 828bdb06f7e81b91792cd716ca34080c95c1a116 [Len: 1219]
# Processing docID: f7026692f134a65a599ed94c02199f9735baf7dc [Len: 1105]
# Processing docID: 5d724fd6b5bd4ce9a79bbd3d7a07d0f5c204ce80 [Len: 1749]
# Processing docID: 1069688a257849848d15032b7e300835f7eb950c [Len: 5058]
# Processing docID: 859fc5e0c7ae10e2bbe36a3f320ef554427fb3a3 [Len: 1217]
# Processing docID: 4dde45295572ed5313d81ac306fb94a42184efe3 [Len: 633]
# Processing docID: a8faa3df0f5fac742af7032d1be40af079c92e19 [Len: 5126]
# Processing docID: 9c4712642c8e611b94cf40c8a5cc238e95eaa960 [Len: 6349]
# Processing docID: b39e8ec7fd5a318380596dabdf145f69a115eb47 [Len: 5205]
# Processing docID: c31e42e1b16d1d9847f3cdffd99df33c046c7d0d [Len: 968]
# Processing docID: 0ebdd7ae48243161c56497103fd81de332936a76 [Len: 5058]
# Processing docID: 05842b0ba9efa2098e36e7049739d54582cff04b [Len: 4056]
# [24345 left]...
# Processing docID: 05842b0ba9efa2098e36e7049739d54582cff04b [Len: 4056]
# Processing docID: ea016154d33f176d080ad7344d2b96f94f6e0457 [Len: 2074]
# Processing docID: a0724885011c6565b8256488d606d2631f035db6 [Len: 1975]
# Processing docID: fd8c22c3d920154c8df999a84efd1f5c7873aa10 [Len: 4305]
# Processing docID: 0299a0125c4e085e046bc09fcea9cb806a830dcb [Len: 956]
# Processing docID: 525aafc1d6ee3e29c8019e2e6e62597b0b020979 [Len: 1486]
# Processing docID: 46f19c2b39e463003fd56aa611a08b7e36b08bb8 [Len: 1045]
# Processing docID: 32038680c08cabf926ab10b73fcac157c3627e49 [Len: 1729]
# Processing docID: db3740f1b16a6b6522968a6a5eed62e9bd894493 [Len: 5251]
# Processing docID: f8182c1627f63611b4e835f26b8716a772168164 [Len: 885]
# Processing docID: 6c3b097bd75427763f88286fad775352016c9256 [Len: 3755]
# Processing docID: fea7d4106f59174c530f69a114ca621caf1abadf [Len: 920]
# Processing docID: PMC7498995 [Len: 2491]
# Processing docID: PMC7499002 [Len: 5197]
# Processing docID: PMC7499015 [Len: 2056]
# Processing docID: PMC7499145 [Len: 5205]
# Processing docID: PMC7499312 [Len: 5157]
# Processing docID: PMC7499415 [Len: 5193]
# Processing docID: PMC7499482 [Len: 5118]
# Processing docID: PMC7499505 [Len: 5207]
# [24326 left]...
# Processing docID: PMC7499505 [Len: 5207]
# Processing docID: PMC7499545 [Len: 5181]
# Processing docID: PMC7499572 [Len: 5270]
# Processing docID: PMC7499585 [Len: 5234]
# Processing docID: PMC7499662 [Len: 5129]
# Processing docID: PMC7499738 [Len: 5216]
# Processing docID: PMC7499752 [Len: 387]
# Processing docID: PMC7499792 [Len: 5141]
# Processing docID: PMC7500038 [Len: 5213]
# Processing docID: PMC7500272 [Len: 5170]
# Processing docID: PMC7500425 [Len: 5189]
# Processing docID: PMC7500438 [Len: 5191]
# Processing docID: PMC7500502 [Len: 5174]
# Processing docID: PMC7500722 [Len: 5231]
# Processing docID: PMC7500878 [Len: 230]
# Processing docID: f42bbce0292cd4a507a9a251049cf7e44ca90196 [Len: 1525]
# Processing docID: 7e20a14db584636ae7683d4cc5923972b3557cfa [Len: 535]
# Processing docID: b9091227ed8e62dec75cbc99b492864e26869cb3 [Len: 1741]
# Processing docID: 46b306119a2940667c4ced8f8b9382c592a36a45 [Len: 1322]
# Processing docID: ffa7decbce004a9a05783a3ecdaf3ae55193b028 [Len: 1890]
# [24307 left]...
# Processing docID: ffa7decbce004a9a05783a3ecdaf3ae55193b028 [Len: 1890]
# Processing docID: 6aa448e4895bd531ee542dcf81e065dab6b6deca [Len: 1872]
# Processing docID: b4b54094a9d5bafa9b82f7808696dd3d9780be96 [Len: 650]
# Processing docID: f5b874dd4069f77e82cda11bd9465cd11c57f623 [Len: 1506]
# Processing docID: 90183c66dd509c6470c07b93eeed7a9204e70492 [Len: 1291]
# Processing docID: 42df05822409be06bea8cf5fd3a8ace10a162138 [Len: 5152]
# Processing docID: d94aa75901d9412efd1ed0e578652647da536ad2 [Len: 1939]
# Processing docID: 0654160314c6d0aa528b927d6a258a9003af211a [Len: 1201]
# Processing docID: d163d306fd38fd98739765281ae4bf085366bd08 [Len: 2489]
# Processing docID: 0237c6d5027c3d10c292d1dcf7670b06146c77b5 [Len: 2780]
# Processing docID: 8040eb4acd89383fce7cff41fa961707649d895b [Len: 5140]
# Processing docID: 6ac33c78f020b3f29b1f38141e35d83e577f6544 [Len: 5220]
# Processing docID: 045ba8c46a1166c84be3c38a1c03b74470668264 [Len: 2542]
# Processing docID: ca1b507705d747b23bee46e89276cde5d7d6a508 [Len: 612]
# Processing docID: fc72e929093ce441570e0ad0d1adca9749c268d3 [Len: 5061]
# Processing docID: 64681c7048d21222f5a1c03cef21f5f8704640a8 [Len: 5126]
# Processing docID: 3f9f6565fbc38f4724501977051dfd3efe874d0e [Len: 1893]
# Processing docID: ab47f116a82aa8f2caae90504895dc893e2bc1c9 [Len: 5720]
# Processing docID: 212248bed8e6bb4bc3bb4266c141514dfc8c8287 [Len: 5236]
# Processing docID: 28a3a0b03e7270a5035c7d427b0f6da564140514 [Len: 704]
# Processing docID: 67b6dc3573b38074b8a6d3ffc9d18514c2b909e4 [Len: 3601]
# Processing docID: bad4bebee343b53f8f811b93615145c077c80f36 [Len: 2141]
# [23986 left]...
# Processing docID: bad4bebee343b53f8f811b93615145c077c80f36 [Len: 2141]
# Processing docID: e2889601fe016e40c25b23523235f4d0601a7f89 [Len: 5174]
# Processing docID: 65f9c49d63518d0c3170761868e48840ce32ddb8 [Len: 694]
# Processing docID: 0fa07c5345c5aab078dd8340e92c8bb9e838c9a2 [Len: 2186]
# Processing docID: 562ab5f55a4d22a74ec54d21a9e06eeabf3c630f [Len: 1595]
# Processing docID: ccfa1bd8b582771efb1cf881fad1c5bbbaf8952b [Len: 734]
# Processing docID: baf0f82002d6c2ad970b71e112cf4cd7ed3a9925 [Len: 2149]
# Error - Will Apply Empty Concepts:  {'code': 'InternalServerError', 'message': 'Processing failed unexpectedly. Please try again later.'}
# Processing docID: 9ca1029a0dbe55242b4d3fe7f63130b26f7690bf [Len: 5059]
# Processing docID: 5f6aab05d62dc2999e631ea247c78dbf8457ac5d [Len: 2780]
# Processing docID: e288b901ea1bbade8dddf6805f51faa19272cc03 [Len: 1161]
# Processing docID: e6a6c866fff46f0b49d32b3d12aeacc76afff41b [Len: 2304]
# Processing docID: dc09e66ef91697b0711cb2f7ea0abac772c7a408 [Len: 1568]
# Processing docID: 99b7ef09280bcf5bf710ce9e67bf3e95064b7994 [Len: 5058]
# Processing docID: b50979a69b63508a904d75a8d4d55cb0796a3bf3 [Len: 2294]
# Processing docID: 3d92e812e0034362bf681b4df4ffb0f4bf2ce82c [Len: 5189]
# Processing docID: 21561db2cc90c6f3ab9a844c6a824c22eb1915f2 [Len: 559]
# Processing docID: bef89bd6cfdfe304a8e8fd690aced617d62e45db [Len: 2289]
# Processing docID: 890d1551ef179917e20e8138499b5fccebf59f03 [Len: 1613]
# Processing docID: 9d3e8380d5f5b9d8a2230435d27db70276efa577 [Len: 2389]
# Processing docID: 2c6a5b96ec00e8d016dfa3d3ca00df8ebd97917f [Len: 1868]
# [23966 left]...
# Processing docID: 04340f4d24c27bec0e6aab29ff12aff2c827f763 [Len: 2935]
# Processing docID: 8ad9b9c67fb33dc6312ec83cc0e7b60730959258 [Len: 5286]
# Processing docID: bd0d4d88fa61d1bf3e17e31e9fbb180a38e39ca3 [Len: 3189]
# Processing docID: PMC7491998 [Len: 2045]
# Processing docID: PMC7492005 [Len: 5178]
# Processing docID: PMC7492058 [Len: 840]
# Processing docID: PMC7492085 [Len: 5207]
# Processing docID: PMC7492135 [Len: 5182]
# Processing docID: PMC7492238 [Len: 5260]
# Processing docID: PMC7492795 [Len: 5192]
# Processing docID: PMC7492832 [Len: 5226]
# Processing docID: PMC7492858 [Len: 5212]
# Processing docID: PMC7493062 [Len: 5207]
# Processing docID: PMC7493295 [Len: 5161]
# Processing docID: PMC7493732 [Len: 5183]
# Processing docID: PMC7493758 [Len: 997]
# Processing docID: PMC7493772 [Len: 5188]
# Processing docID: PMC7493798 [Len: 5159]
# Processing docID: PMC7493808 [Len: 5251]
# Processing docID: PMC7494258 [Len: 5249]
# [23947 left]...
# Processing docID: PMC7494258 [Len: 5249]
# Processing docID: PMC7494308 [Len: 5237]
# Processing docID: PMC7494438 [Len: 5147]
# Processing docID: PMC7494452 [Len: 5182]
# Processing docID: PMC7494502 [Len: 5169]
# Processing docID: PMC7494515 [Len: 5230]
# Processing docID: PMC7494658 [Len: 164]
# Processing docID: PMC7495118 [Len: 5144]
# Processing docID: PMC7480772 [Len: 5218]
# Processing docID: PMC7480798 [Len: 236]
# Processing docID: PMC7480978 [Len: 5213]
# Processing docID: PMC7480992 [Len: 5148]
# Processing docID: PMC7481115 [Len: 5210]
# Processing docID: PMC7481128 [Len: 5154]
# Processing docID: PMC7481542 [Len: 5218]
# Processing docID: PMC7481762 [Len: 5193]
# Processing docID: PMC7481838 [Len: 5196]
# Processing docID: PMC7481902 [Len: 5268]
# Processing docID: PMC7482055 [Len: 5245]
# Processing docID: PMC7482545 [Len: 5205]
# [23928 left]...
# Processing docID: PMC7482545 [Len: 5205]
# Processing docID: PMC7482598 [Len: 5155]
# Processing docID: PMC7482868 [Len: 5044]
# Processing docID: PMC7482882 [Len: 5211]
# Processing docID: PMC7482958 [Len: 5172]
# Processing docID: PMC7483018 [Len: 4244]
# Processing docID: PMC7483045 [Len: 5173]
# Processing docID: PMC7486208 [Len: 5199]
# Processing docID: PMC7486288 [Len: 3367]
# Processing docID: PMC7486585 [Len: 5246]
# Processing docID: PMC7486622 [Len: 5181]
# Processing docID: PMC7486675 [Len: 5150]
# Processing docID: PMC7486725 [Len: 5165]
# Processing docID: PMC7486752 [Len: 5212]
# Processing docID: PMC7486868 [Len: 5254]
# Processing docID: PMC7486972 [Len: 5206]
# Processing docID: PMC7487072 [Len: 5178]
# Processing docID: PMC7487085 [Len: 5156]
# Processing docID: PMC7487265 [Len: 5181]
# Processing docID: PMC7487445 [Len: 5149]
# [23909 left]...
# Processing docID: PMC7487445 [Len: 5149]
# Processing docID: PMC7487522 [Len: 5179]
# Processing docID: PMC7487742 [Len: 5301]
# Processing docID: PMC7487805 [Len: 5195]
# Processing docID: PMC7488215 [Len: 5284]
# Processing docID: PMC7489195 [Len: 5187]
# Processing docID: PMC7489218 [Len: 550]
# Processing docID: PMC7489232 [Len: 5239]
# Processing docID: PMC7489245 [Len: 271]
# Processing docID: PMC7489272 [Len: 5226]
# Processing docID: PMC7489452 [Len: 4409]
# Processing docID: PMC7489528 [Len: 5206]
# Processing docID: PMC7489775 [Len: 5267]
# Processing docID: PMC7489892 [Len: 5174]
# Processing docID: PMC7489928 [Len: 4492]
# Processing docID: PMC7489942 [Len: 3359]
# Processing docID: PMC7490205 [Len: 4011]
# Processing docID: PMC7490245 [Len: 5147]
# Processing docID: PMC7490258 [Len: 5191]
# Processing docID: PMC7490285 [Len: 327]
# [23890 left]...
# Processing docID: PMC7490285 [Len: 327]
# Processing docID: PMC7483058 [Len: 5232]
# Processing docID: PMC7483085 [Len: 5178]
# Processing docID: PMC7483432 [Len: 5180]
# Processing docID: PMC7483498 [Len: 5233]
# Processing docID: PMC7484565 [Len: 5278]
# Processing docID: PMC7484578 [Len: 5232]
# Processing docID: PMC7484615 [Len: 5217]
# Processing docID: PMC7484628 [Len: 5273]
# Processing docID: PMC7484705 [Len: 5204]
# Processing docID: PMC7495145 [Len: 396]
# Processing docID: PMC7495185 [Len: 901]
# Processing docID: PMC7495248 [Len: 5208]
# Processing docID: PMC7495725 [Len: 5270]
# Processing docID: PMC7496948 [Len: 5252]
# Processing docID: PMC7497282 [Len: 5194]
# Processing docID: PMC7498115 [Len: 5250]
# Processing docID: PMC7498195 [Len: 5195]
# Processing docID: PMC7498218 [Len: 2291]
# Processing docID: PMC7498232 [Len: 1854]
# [23871 left]...
# Processing docID: PMC7498232 [Len: 1854]
# Processing docID: PMC7498308 [Len: 5229]
# Processing docID: PMC7498412 [Len: 5244]
# Processing docID: PMC7484745 [Len: 5141]
# Processing docID: PMC7484925 [Len: 5348]
# Processing docID: PMC7485195 [Len: 3965]
# Processing docID: PMC7485205 [Len: 2651]
# Processing docID: PMC7485285 [Len: 5193]
# Processing docID: PMC7485452 [Len: 5213]
# Processing docID: PMC7485542 [Len: 5161]
# Processing docID: PMC7485595 [Len: 5174]
# Processing docID: PMC7486132 [Len: 5187]
# Processing docID: PMC7486145 [Len: 4841]
# Processing docID: PMC7486158 [Len: 3154]
# Processing docID: 345d90d9e415f474f1d4aa8417cbc389e0ff738e [Len: 5058]
# Processing docID: e8fb9eb64e15b9402f822c4379ffee24276f859e [Len: 5058]
# Processing docID: 0013014a7a3d77fa6df2dd77654d58dbc155c2c9 [Len: 2764]
# Processing docID: 3cfe053065a53551b5eb3a5b09d0f80b7125656a [Len: 1272]
# Processing docID: 514497304aa73ba56195c12cdd91671edc080cad [Len: 2118]
# Processing docID: a4cb6f6f690c1367e4a5c7b2ac1292a7283a0368 [Len: 539]
# [23852 left]...
# Processing docID: a4cb6f6f690c1367e4a5c7b2ac1292a7283a0368 [Len: 539]
# Processing docID: 8d60fcd38f8a841bd0be4f8763164c19b2dc82e8 [Len: 5058]
# Processing docID: 857bab4e356fc8bf8281fffc9f997deb7b6d1adf [Len: 1343]
# Processing docID: f697f347604205bedbc480fb493e326db6bf20c9 [Len: 2951]
# Processing docID: 90573973e883b568b4f02fd700013199e5318a20 [Len: 1002]
# Processing docID: 0deebdbf932adca82b09186095e21094f19eadba [Len: 2096]
# Processing docID: 7b1a4466b70b9154608825bbf1661283ab697177 [Len: 1193]
# Processing docID: 01ea33218ae0174421a0a759a86278e1b8a4becd [Len: 1905]
# Processing docID: eeb7b153d2cd9b4aa3ce620bb2f1e538596a9309 [Len: 2046]
# Processing docID: 18640354749f2c47c7f1acd12fdf2ba4dd320040 [Len: 3087]
# Processing docID: 21a641ab936a77b8e581b8dd1c8898062aceed5a [Len: 1341]
# Processing docID: 0a680b0232af1c58e05b4e372910b9678222eb07 [Len: 1123]
# Processing docID: 7da1bcb9da29e56c7b883598abd14736f29b1f78 [Len: 5192]
# Processing docID: 73215d1a75b77c279955ab4e0a77b3427fe988f8 [Len: 1981]
# Processing docID: a0ac7c3c88c001005702273a1f9c3de68555d2d1 [Len: 5058]
# Processing docID: 71e8fe0fd99b27065e4b11e52527866e0b4e612e [Len: 5058]
# Processing docID: a50ba5e0a30631ef17de0d9666beb76ce77cf0a1 [Len: 5213]
# Processing docID: 809dbbe5c0b628ff4e8c41a9e29947e2744bd871 [Len: 891]
# [23703 left]...
# Processing docID: 809dbbe5c0b628ff4e8c41a9e29947e2744bd871 [Len: 891]
# Processing docID: dfb46d50598287f6555e97628181f5b804a43e49 [Len: 4554]
# Processing docID: bb7c28a770c3f6aea300ca54155943ccff30af22 [Len: 5058]
# Processing docID: 85d9111776f3e7f494bf7d956043a76a9092a1c8 [Len: 3421]
# Processing docID: 9a7dc99c3ad024c7272a2c0a98ddc85b555e448a [Len: 5127]
# Processing docID: 3e46ddff80143387823993079584f2ea469c45c4 [Len: 2749]
# Processing docID: 860e7f572c9ccb82554eca573e25a3dc158cb7e7 [Len: 1467]
# Processing docID: af3644bba8b048a40e32a539cf84d79b21a4a797 [Len: 1076]
# Processing docID: 41323e031b5ad8b22f5d47192d2453f68153e485 [Len: 5243]
# Processing docID: 02c35cca16ff9694b0b14cac5a7b5ea29a886c8e [Len: 5166]
# Processing docID: bc9b561c1ff80e2e44d50e711e1a3f8464d2d488 [Len: 5259]
# Processing docID: dc017ff3fd0fe6290862f240d60e8360068280cd [Len: 4462]
# Processing docID: 540ae945f8f80e43cb5b0c3c6e32bdc355b2a69c [Len: 5063]
# Processing docID: fa4c962ca36e9f57dd5c3151fd0e03b00bd12fee [Len: 1636]
# Processing docID: 5262ed55ff224308c9ddb536fefd0dc4cc97d763 [Len: 2349]
# Processing docID: 180a76043974301a46750add1e83e873baa0262c [Len: 1445]
# Processing docID: dc8fc2a483ebe314c5e3eed93e5bd940570b3557 [Len: 5058]
# Processing docID: 9e0793211b41e0d786df224d6245c6415d903a91 [Len: 1273]
# Processing docID: ebadaaaf1d5948fae5ecf78a61d18a7db3e0ca4b [Len: 1610]
# Processing docID: 74066107188f8ac2d2f7dce367987bd2cf55d12b [Len: 1052]
# [23685 left]...
# Processing docID: ebadaaaf1d5948fae5ecf78a61d18a7db3e0ca4b [Len: 1610]
# Processing docID: 74066107188f8ac2d2f7dce367987bd2cf55d12b [Len: 1052]
# Processing docID: 51120de4acc630884d830500c358f01e498a4a92 [Len: 5162]
# ...
# Processing docID: PMC7465085 [Len: 5201]
# Processing docID: PMC7465292 [Len: 5154]
# Processing docID: PMC7465418 [Len: 5166]
# Processing docID: PMC7465755 [Len: 5205]
# Processing docID: PMC7465935 [Len: 5156]
# Processing docID: PMC7458285 [Len: 2128]
# Processing docID: PMC7458502 [Len: 293]
# Processing docID: PMC7459158 [Len: 5457]
# Processing docID: PMC7459248 [Len: 5195]
# Processing docID: PMC7459262 [Len: 5178]
# Processing docID: PMC7459442 [Len: 3476]
# Processing docID: PMC7459545 [Len: 5191]
# Processing docID: PMC7459558 [Len: 5188]
# Processing docID: PMC7459608 [Len: 5252]
# Processing docID: PMC7459712 [Len: 5231]
# Processing docID: PMC7459752 [Len: 5155]
# [23475 left]...
# Processing docID: PMC7459802 [Len: 5184]
# Processing docID: PMC7459855 [Len: 5177]
# Processing docID: PMC7459895 [Len: 5237]
# Processing docID: PMC7459905 [Len: 5201]
# Processing docID: PMC7459945 [Len: 4298]
# Processing docID: PMC7459985 [Len: 5250]
# Processing docID: PMC7456292 [Len: 5237]
# Processing docID: PMC7456302 [Len: 5167]
# Processing docID: PMC7456445 [Len: 5211]
# Processing docID: PMC7456678 [Len: 2489]
# Processing docID: PMC7457552 [Len: 5198]
# Processing docID: PMC7457578 [Len: 5257]
# Processing docID: PMC7457602 [Len: 5178]
# Processing docID: PMC7457615 [Len: 5182]
# Processing docID: PMC7457888 [Len: 5189]
# Processing docID: PMC7457938 [Len: 5175]
# Processing docID: PMC7457965 [Len: 5223]
# Processing docID: PMC7458052 [Len: 5159]
# Processing docID: PMC7458128 [Len: 5231]
# Processing docID: PMC7460028 [Len: 5209]
# [23456 left]...
# Processing docID: PMC7460028 [Len: 5209]
# Processing docID: PMC7460042 [Len: 5276]
# Processing docID: PMC7460442 [Len: 5162]
# Processing docID: PMC7460608 [Len: 5262]
# Processing docID: PMC7460945 [Len: 5169]
# Processing docID: PMC7460972 [Len: 5158]
# Processing docID: PMC7460985 [Len: 225]
# Processing docID: PMC7461018 [Len: 5239]
# Processing docID: PMC7461032 [Len: 4081]
# Processing docID: PMC7461072 [Len: 4233]
# Processing docID: PMC7461085 [Len: 5205]
# Processing docID: PMC7461162 [Len: 5197]
# Processing docID: PMC7461175 [Len: 3778]
# Processing docID: PMC7461225 [Len: 3087]
# Processing docID: PMC7461238 [Len: 5250]
# Processing docID: PMC7461278 [Len: 5149]
# Processing docID: PMC7454708 [Len: 4188]
# Processing docID: PMC7454788 [Len: 5163]
# Processing docID: PMC7454838 [Len: 1792]
# Processing docID: PMC7454942 [Len: 5213]
# [23437 left]...
# Processing docID: PMC7454942 [Len: 5213]
# Processing docID: PMC7455095 [Len: 5196]
# Processing docID: PMC7455172 [Len: 5211]
# Processing docID: PMC7455235 [Len: 5230]
# Processing docID: PMC7455495 [Len: 5174]
# Processing docID: PMC7455518 [Len: 535]
# Processing docID: PMC7455545 [Len: 5208]
# Processing docID: PMC7455675 [Len: 5358]
# Processing docID: PMC7455778 [Len: 5173]
# Processing docID: PMC7455792 [Len: 5161]
# Processing docID: PMC7455802 [Len: 5139]
# Processing docID: PMC7455815 [Len: 5238]
# Processing docID: PMC7456265 [Len: 5185]
# Processing docID: PMC7456278 [Len: 5188]
# Processing docID: PMC7451495 [Len: 5257]
# Processing docID: PMC7451545 [Len: 5191]
# Processing docID: PMC7451972 [Len: 5205]
# Processing docID: PMC7452368 [Len: 5205]
# Processing docID: PMC7453138 [Len: 5179]
# Processing docID: PMC7453242 [Len: 5260]
# [23417 left]...
# Processing docID: PMC7453295 [Len: 631]
# Processing docID: PMC7453358 [Len: 5149]
# Processing docID: PMC7453448 [Len: 5238]
# Processing docID: PMC7453732 [Len: 5207]
# Processing docID: PMC7453862 [Len: 2079]
# Processing docID: PMC7453875 [Len: 1449]
# Processing docID: PMC7454052 [Len: 5181]
# Processing docID: PMC7454065 [Len: 5152]
# Processing docID: PMC7454465 [Len: 5175]
# Processing docID: PMC7462475 [Len: 5240]
# Processing docID: PMC7462525 [Len: 5190]
# Processing docID: PMC7462538 [Len: 5300]
# Processing docID: PMC7462552 [Len: 2596]
# Processing docID: PMC7462565 [Len: 5229]
# Processing docID: PMC7462578 [Len: 4676]
# Processing docID: PMC7462592 [Len: 5206]
# Processing docID: PMC7462628 [Len: 5182]
# Processing docID: PMC7462642 [Len: 5218]
# Processing docID: PMC7462732 [Len: 5284]
# Processing docID: PMC7462785 [Len: 792]
# [23398 left]...
# Processing docID: PMC7462785 [Len: 792]
# Processing docID: PMC7462835 [Len: 3645]
# Processing docID: PMC7462888 [Len: 5195]
# Processing docID: PMC7462965 [Len: 5224]
# Processing docID: PMC7443962 [Len: 5284]
# Processing docID: PMC7444282 [Len: 5185]
# Processing docID: PMC7445335 [Len: 4291]
# Processing docID: PMC7447212 [Len: 4078]
# Processing docID: PMC7447292 [Len: 5194]
# Processing docID: PMC7448668 [Len: 5193]
# Processing docID: PMC7448822 [Len: 413]
# Processing docID: PMC7449182 [Len: 5216]
# Processing docID: PMC7449412 [Len: 5196]
# Processing docID: PMC7449465 [Len: 5221]
# Processing docID: PMC7449478 [Len: 5198]
# Processing docID: PMC7450285 [Len: 5300]
# Processing docID: PMC7450375 [Len: 5202]
# Processing docID: PMC7450528 [Len: 5150]
# Processing docID: PMC7461292 [Len: 3342]
# Processing docID: PMC7461315 [Len: 5267]
# [23379 left]...
# Processing docID: PMC7461315 [Len: 5267]
# Processing docID: PMC7461328 [Len: 221]
# Processing docID: PMC7461368 [Len: 5222]
# Processing docID: PMC7461395 [Len: 5198]
# Processing docID: PMC7461418 [Len: 5215]
# Processing docID: PMC7461472 [Len: 5227]
# Processing docID: PMC7461485 [Len: 430]
# Processing docID: PMC7461498 [Len: 278]
# Processing docID: PMC7461522 [Len: 5235]
# Processing docID: PMC7461742 [Len: 5161]
# Processing docID: PMC7461755 [Len: 5181]
# Processing docID: PMC7462112 [Len: 5225]
# Processing docID: PMC7462125 [Len: 5225]
# Processing docID: PMC7462165 [Len: 5247]
# Processing docID: PMC7462332 [Len: 5207]
# Processing docID: ad72ea5adfaaf236fc9304ffa850c0d305847803 [Len: 5123]
# Processing docID: f829194cf74c2dc93ddcee3137b19e9e42d83836 [Len: 5176]
# Processing docID: 7305eb5c4c054d14dd82b0d7385f157509907ff8 [Len: 2001]
# Processing docID: 1d82cd5f3bb68c2f652543c7c925617f99c34c45 [Len: 1942]
# Processing docID: c1a4b680b116bdc0313dbca800c2ee816e1ffe58 [Len: 2467]
# [23360 left]...
# Processing docID: c1a4b680b116bdc0313dbca800c2ee816e1ffe58 [Len: 2467]
# Processing docID: e7ad1b8d07917dd0433fff3e29ba1cf7d4e2ad0d [Len: 1221]
# Processing docID: 41256ed9a9c6ef1ecda65bc3a601c5f4c372b37c [Len: 376]
# Processing docID: 6b47f1015c36094cbe3b58417184dd5c6322193c [Len: 1865]
# Processing docID: 816663293eb316791fb0f86281f1ecc23f9a7d2f [Len: 1432]
# Processing docID: 9be585309f7da28c58f057f91c8bcc28c9231705 [Len: 1531]
# Processing docID: 3f2f863f29c281626823f0211b2e01845e29e98d [Len: 1774]
# Processing docID: 7dad5281b574d81a88280d92759072d395ad552b [Len: 1048]
# Processing docID: c8c3795acd9a8d36ac932c67b056ddf04db04e8b [Len: 1988]
# Processing docID: 8bee9f4612fa395c36dc6c6a5ba17c9ed06b7879 [Len: 1862]
# Processing docID: 4b3e33a071450eae66f59fd5753feb8fc287cd73 [Len: 1858]
# Processing docID: 8ae694fa3d1ae47d23fe0f272405d613bf97439b [Len: 1937]
# Processing docID: 490282c80b0fef070144a930372804fecfb67f95 [Len: 2532]
# Processing docID: b6975756b4628ae9b8577ccc2986db5a42fe2ed8 [Len: 1909]
# Processing docID: ae0036809ae17a921e5ded76afc5d970e331f308 [Len: 2393]
# Processing docID: 116f8479e3a44b5fd23d9aa50541ddd0f8ef4f0e [Len: 1618]
# Processing docID: 13c897ccd8094cbfdffedd5a77c0aa9379532059 [Len: 2161]
# Processing docID: 42afd25fe11d80b4b3b2e3857352e5ae262b2b3b [Len: 1825]
# Processing docID: f2823230db4dbb1870e9636718eb4880b437119d [Len: 1365]
# Processing docID: c104a03078bbdbdc76d32202d91491120338133a [Len: 1161]
# [23342 left]...
# Processing docID: f2823230db4dbb1870e9636718eb4880b437119d [Len: 1365]
# Processing docID: c104a03078bbdbdc76d32202d91491120338133a [Len: 1161]
# Processing docID: 515afeaaf3fe872f6152e719abb8af58493e9956 [Len: 2598]
# Processing docID: 26cab34bedb8de68b8333a6a351748c46b2ce2d0 [Len: 1735]
# Processing docID: e7827639b05e8c5849514946cab17711bd3122d5 [Len: 2063]
# Processing docID: 4d7996f4cb42cfe21bbc77692e86b878ad7dfae4 [Len: 1819]
# Processing docID: 5be6de903f5ac982efc8df3bee454eb149a8b510 [Len: 2924]
# Processing docID: d6ab96a72bba91ef9defb17b7beb3008620f3c97 [Len: 5127]
# Processing docID: ef6f74800c3b79bedcdddab90ca8d9d35d20d776 [Len: 1332]
# Processing docID: 48a674225075896bdab9d0981e64a1cd79e54421 [Len: 2576]
# Processing docID: 78facba14390a9d0465a9a983d963f7370f87e30 [Len: 2461]
# Processing docID: 9e23c84882874abb67a2a5d55bc27d7bc30a7d73 [Len: 6129]
# Processing docID: bc8d3ef33f45495a626feca8321f92dc3dd3db85 [Len: 4056]
# Processing docID: PMC7501778 [Len: 5249]
# Processing docID: PMC7501792 [Len: 3217]
# Processing docID: PMC7501828 [Len: 5165]
# Processing docID: PMC7501842 [Len: 161]
# Processing docID: PMC7501998 [Len: 5254]
# Processing docID: PMC7502032 [Len: 5162]
# Processing docID: PMC7502238 [Len: 5251]
# [23323 left]...
# Processing docID: PMC7502238 [Len: 5251]
# Processing docID: PMC7502252 [Len: 5170]
# Processing docID: PMC7502278 [Len: 5212]
# Processing docID: PMC7502652 [Len: 4924]
# Processing docID: PMC7502678 [Len: 5194]
# Processing docID: PMC7503048 [Len: 5202]
# Processing docID: PMC7503112 [Len: 5234]
# Processing docID: PMC7503192 [Len: 5226]
# Processing docID: PMC7503345 [Len: 5285]
# Processing docID: PMC7503435 [Len: 5198]
# Processing docID: PMC7506485 [Len: 3748]
# Processing docID: PMC7506498 [Len: 5176]
# Processing docID: PMC7506805 [Len: 5207]
# Processing docID: PMC7507592 [Len: 5179]
# Processing docID: PMC7508052 [Len: 5191]
# Processing docID: PMC7508168 [Len: 3057]
# Processing docID: PMC7508232 [Len: 5189]
# Processing docID: PMC7508245 [Len: 5203]
# Processing docID: PMC7508425 [Len: 5208]
# Processing docID: PMC7508492 [Len: 5162]
# [23304 left]...
# Processing docID: PMC7508492 [Len: 5162]
# Processing docID: PMC7509222 [Len: 5123]
# Processing docID: PMC7509495 [Len: 5289]
# Processing docID: PMC7509532 [Len: 5190]
# Processing docID: PMC7505015 [Len: 5156]
# Processing docID: PMC7505028 [Len: 5194]
# Processing docID: PMC7505042 [Len: 5307]
# Processing docID: PMC7505068 [Len: 452]
# Processing docID: PMC7505095 [Len: 5168]
# Processing docID: PMC7505132 [Len: 5173]
# Processing docID: PMC7505222 [Len: 5252]
# Processing docID: PMC7505482 [Len: 5235]
# Processing docID: PMC7505572 [Len: 3659]
# Processing docID: PMC7505598 [Len: 5176]
# Processing docID: PMC7505622 [Len: 5226]
# Processing docID: PMC7505635 [Len: 5178]
# Processing docID: PMC7505648 [Len: 180]
# Processing docID: PMC7505675 [Len: 5224]
# Processing docID: PMC7505792 [Len: 5214]
# Processing docID: PMC7506175 [Len: 5181]
# [23285 left]...
# Processing docID: PMC7506175 [Len: 5181]
# Processing docID: PMC7500902 [Len: 5202]
# Processing docID: PMC7500915 [Len: 5150]
# Processing docID: PMC7500942 [Len: 5146]
# Processing docID: PMC7501002 [Len: 5219]
# Processing docID: PMC7501015 [Len: 5157]
# Processing docID: PMC7501068 [Len: 5198]
# Processing docID: PMC7501082 [Len: 5194]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-80b4ce44ff02> in <module>
#      14         print ("Processing docID:", docID, "[Len: " + str(len(str(ta_health_doc))) + "]")
#      15
# ---> 16         ta_health_resp = processFile(ta_health_doc)
#      17         if 'error' not in ta_health_resp:
#      18             search_upload = createSearchUploadDoc(docID, ta_health_resp)
#
# <ipython-input-8-790526ba639c> in processFile(data)
#       1 def processFile(data):
#       2     try:
# ----> 3         json_response = requests.post(url = globals.ta_base_url, json= data).json()
#       4         return json_response
#       5     except Exception as ex:
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda/envs/py37_default/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /anaconda/envs/py37_default/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /anaconda/envs/py37_default/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /anaconda/envs/py37_default/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /anaconda/envs/py37_default/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /anaconda/envs/py37_default/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /anaconda/envs/py37_default/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
