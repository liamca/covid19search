# %%
# Do a test query against container

# %%
import json
import requests
from pprint import pprint

# %%
headers = {'Content-Type': 'application/json'}

base_url = "http://52.149.61.134:5000/text/analytics/v3.0-preview.1/domains/health"
body = {
  "documents": [
    {
      "language": "en",
      "id": "1",
      "text": "Morquio syndrome, also known as Mucopolysaccharidosis Type IV (MPS IV), is a rare metabolic disorder in which the body cannot process certain types of sugar molecules called glycosaminoglycans (AKA GAGs, or mucopolysaccharides)."
    }
  ]
}

# %%
response  = requests.post(base_url, headers=headers, json=body)
index = response.json()
pprint(index)
# Out:
# {'documents': [{'entities': [{'id': '0',
#                               'isNegated': False,
#                               'length': 16,
#                               'links': [{'dataSource': 'UMLS',
#                                          'id': 'C0026707'},
#                                         {'dataSource': 'SNOMEDCT_US',
#                                          'id': '378007'},
#                                         {'dataSource': 'ICPC2ICD10ENG',
#                                          'id': 'MTHU077309'},
#                                         {'dataSource': 'CSP',
#                                          'id': '1849-6163'},
#                                         {'dataSource': 'MEDCIN', 'id': '33586'},
#                                         {'dataSource': 'MSH', 'id': 'D009085'},
#                                         {'dataSource': 'RCD', 'id': 'C3754'},
#                                         {'dataSource': 'MTHICD9',
# ...
